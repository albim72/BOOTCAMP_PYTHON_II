# %%
from scipy import stats
from scipy import optimize
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %%
x = np.array([3.5,1.1,3.2,2.8,6.7,4.4,0.9,2.2])
np.mean(x)
# Out:
# 3.1

# %%
np.median(x)
# Out:
# 3.0

# %%
x.min(), x.max()
# Out:
# (0.9, 6.7)

# %%
x.var()
# Out:
# 3.0700000000000007

# %%
x.std()
# Out:
# 1.7521415467935233

# %%
x.var(ddof=1)
# Out:
# 3.5085714285714293

# %%
x.std(ddof=1)
# Out:
# 1.8731181032095732

# %%
#liczby losowe
np.random.randint(10,size=10)
# Out:
# <pre>array([0, 9, 1, 6, 1, 7, 7, 7, 6, 5])</pre>

# %%
np.random.randint(low=10,high=20,size=(2,10))
# Out:
# <pre>array([[19, 15, 17, 19, 18, 18, 12, 12, 15, 13],
#        [10, 14, 14, 14, 18, 16, 16, 11, 16, 19]])</pre>

# %%
fig,axes = plt.subplots(1,3,figsize=(12,3))
axes[0].hist(np.random.rand(10000))
axes[0].set_title("rand")
axes[1].hist(np.random.randn(10000))
axes[1].set_title("randn")
axes[2].hist(np.random.randint(low=1,high=10,size=10000),bins=9,align='left')
axes[2].set_title("randint(low=1, high=10)")
# Out:
# Text(0.5, 1.0, 'randint(low=1, high=10)')

# %%
np.random.seed(123)
np.random.choice(10,5,replace=False)
# Out:
# <pre>array([4, 0, 7, 5, 8])</pre>

# %%
prng = np.random.RandomState(123456)
prng.randn(2,4)
# Out:
# <pre>array([[ 0.4691123 , -0.28286334, -1.5090585 , -1.13563237],
#        [ 1.21211203, -0.17321465,  0.11920871, -1.04423597]])</pre>

# %%
prng.chisquare(1,size=(2,2))
# Out:
# <pre>array([[2.47196274, 0.04276481],
#        [0.71938874, 0.23180551]])</pre>

# %%
prng.standard_t(1,size=(2,3))
# Out:
# <pre>array([[ 0.70628038,  2.38731501, -2.05593833],
#        [ 1.48934807,  0.60973704, -0.78649795]])</pre>

# %%
prng.exponential(3,size=(5,5))
# Out:
# <pre>array([[0.31520422, 3.97950877, 0.0500487 , 1.96977756, 0.30257491],
#        [2.06332292, 5.475259  , 6.82880114, 3.9569337 , 4.26544584],
#        [2.4674258 , 1.91301213, 0.44817448, 0.29767524, 8.55522509],
#        [0.43195492, 2.98843424, 3.06135771, 1.7047805 , 0.50826478],
#        [5.95477283, 3.44699873, 0.2688188 , 2.50484102, 0.48693869]])</pre>
